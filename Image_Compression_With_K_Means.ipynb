# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.cluster import KMeans

# %%
Img=Image.open("/content/Screenshot 2025-10-24 232139.png").convert('RGB')
img=np.array(Img)

# %%
plt.imshow(img)
plt.axis("off")
plt.show()
#Original

# %%
h,w,ch=img.shape

# %%
h
# Out:
# 640

# %%
w
# Out:
# 452

# %%
ch
# Out:
# 3

# %%
img=img.reshape([-1,3])

# %%
K=64

# %%
model=KMeans(n_clusters=K)

# %%
model.fit(img)
# Out:
# KMeans(n_clusters=64)

# %%
c=model.cluster_centers_

# %%
labels=model.labels_

# %%
labels.shape
# Out:
# (289280,)

# %%
new_img=c[labels].astype(np.uint8)

# %%
new_img=new_img.reshape(h,w,ch)

# %%
new_img.shape
# Out:
# (640, 452, 3)

# %%
plt.imshow(new_img)
plt.axis("off")
plt.show()
#Compressed

# %%
Image.fromarray(new_img).save("New_img_compressed.png")
